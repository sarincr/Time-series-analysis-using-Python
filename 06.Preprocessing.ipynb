# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pylab as plt

# %%
# %matplotlib inline

# %%
dataset=pd.read_csv("daily-min-temperatures.csv")

# %%
dataset.head
# Out:
# <bound method NDFrame.head of             Date  Temp
# 0     1981-01-01  20.7
# 1     1981-01-02  17.9
# 2     1981-01-03  18.8
# 3     1981-01-04  14.6
# 4     1981-01-05  15.8
# 5     1981-01-06  15.8
# 6     1981-01-07  15.8
# 7     1981-01-08  17.4
# 8     1981-01-09  21.8
# 9     1981-01-10  20.0
# 10    1981-01-11  16.2
# 11    1981-01-12  13.3
# 12    1981-01-13  16.7
# 13    1981-01-14  21.5
# 14    1981-01-15  25.0
# 15    1981-01-16  20.7
# 16    1981-01-17  20.6
# 17    1981-01-18  24.8
# 18    1981-01-19  17.7
# 19    1981-01-20  15.5
# 20    1981-01-21  18.2
# 21    1981-01-22  12.1
# 22    1981-01-23  14.4
# 23    1981-01-24  16.0
# 24    1981-01-25  16.5
# 25    1981-01-26  18.7
# 26    1981-01-27  19.4
# 27    1981-01-28  17.2
# 28    1981-01-29  15.5
# 29    1981-01-30  15.1
# ...          ...   ...
# 3620  1990-12-02  13.2
# 3621  1990-12-03  16.2
# 3622  1990-12-04  17.3
# 3623  1990-12-05  20.5
# 3624  1990-12-06  20.2
# 3625  1990-12-07  19.4
# ...

# %%
dataset['Date']=pd.to_datetime(dataset['Date'],infer_datetime_format=True)

# %%
dataset['Date']
# Out:
# 0      1981-01-01
# 1      1981-01-02
# 2      1981-01-03
# 3      1981-01-04
# 4      1981-01-05
# 5      1981-01-06
# 6      1981-01-07
# 7      1981-01-08
# 8      1981-01-09
# 9      1981-01-10
# 10     1981-01-11
# 11     1981-01-12
# 12     1981-01-13
# 13     1981-01-14
# 14     1981-01-15
# 15     1981-01-16
# 16     1981-01-17
# 17     1981-01-18
# 18     1981-01-19
# 19     1981-01-20
# 20     1981-01-21
# 21     1981-01-22
# 22     1981-01-23
# 23     1981-01-24
# 24     1981-01-25
# 25     1981-01-26
# 26     1981-01-27
# 27     1981-01-28
# 28     1981-01-29
# 29     1981-01-30
#           ...
# 3620   1990-12-02
# 3621   1990-12-03
# 3622   1990-12-04
# 3623   1990-12-05
# 3624   1990-12-06
# 3625   1990-12-07
# 3626   1990-12-08
# 3627   1990-12-09
# 3628   1990-12-10
# 3629   1990-12-11
# 3630   1990-12-12
# 3631   1990-12-13
# 3632   1990-12-14
# 3633   1990-12-15
# 3634   1990-12-16
# 3635   1990-12-17
# 3636   1990-12-18
# 3637   1990-12-19
# 3638   1990-12-20
# ...

# %%
IndexDataset=dataset.set_index(['Date'])

# %%
plt.plot(IndexDataset)

# %%
rmean=IndexDataset.rolling(window=12).mean()

# %%
rmean
# Out:
#                  Temp
# Date
# 1981-01-01        NaN
# 1981-01-02        NaN
# 1981-01-03        NaN
# 1981-01-04        NaN
# 1981-01-05        NaN
# 1981-01-06        NaN
# 1981-01-07        NaN
# 1981-01-08        NaN
# 1981-01-09        NaN
# 1981-01-10        NaN
# 1981-01-11        NaN
# 1981-01-12  17.341667
# 1981-01-13  17.008333
# 1981-01-14  17.308333
# 1981-01-15  17.825000
# 1981-01-16  18.333333
# 1981-01-17  18.733333
# 1981-01-18  19.483333
# 1981-01-19  19.641667
# 1981-01-20  19.483333
# 1981-01-21  19.183333
# 1981-01-22  18.525000
# 1981-01-23  18.375000
# 1981-01-24  18.600000
# 1981-01-25  18.583333
# 1981-01-26  18.350000
# 1981-01-27  17.883333
# 1981-01-28  17.591667
# 1981-01-29  17.166667
# 1981-01-30  16.358333
# ...               ...
# 1990-12-02  12.675000
# 1990-12-03  12.775000
# 1990-12-04  13.200000
# 1990-12-05  14.033333
# 1990-12-06  14.791667
# 1990-12-07  15.325000
# 1990-12-08  15.541667
# 1990-12-09  15.983333
# 1990-12-10  15.675000
# ...

# %%
rstd=IndexDataset.rolling(window=12).std()

# %%
rstd
# Out:
#                 Temp
# Date
# 1981-01-01       NaN
# 1981-01-02       NaN
# 1981-01-03       NaN
# 1981-01-04       NaN
# 1981-01-05       NaN
# 1981-01-06       NaN
# 1981-01-07       NaN
# 1981-01-08       NaN
# 1981-01-09       NaN
# 1981-01-10       NaN
# 1981-01-11       NaN
# 1981-01-12  2.575217
# 1981-01-13  2.350032
# 1981-01-14  2.680725
# 1981-01-15  3.474354
# 1981-01-16  3.405165
# 1981-01-17  3.362178
# 1981-01-18  3.640638
# 1981-01-19  3.504661
# 1981-01-20  3.654843
# 1981-01-21  3.594651
# 1981-01-22  4.116955
# 1981-01-23  4.240310
# 1981-01-24  4.012027
# 1981-01-25  4.021043
# 1981-01-26  3.916283
# 1981-01-27  3.343605
# 1981-01-28  3.226160
# 1981-01-29  3.128268
# 1981-01-30  2.040703
# ...              ...
# 1990-12-02  1.831107
# 1990-12-03  1.995051
# 1990-12-04  2.369503
# 1990-12-05  3.006458
# 1990-12-06  3.329608
# 1990-12-07  3.523460
# 1990-12-08  3.439730
# 1990-12-09  2.770570
# 1990-12-10  3.111306
# 1990-12-11  3.376153
# 1990-12-12  3.302570
# ...

# %%
plt.plot(rmean)

# %%
plt.plot(rstd)

# %%
from statsmodels.tsa.stattools import adfuller
# Out:
# /usr/lib/python3/dist-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
dfset=adfuller(IndexDataset["Temp"],autolag='AIC')

# %%
dfset
# Out:
# (-4.444804924611698,
#  0.000247082630036101,
#  20,
#  3629,
#  {'1%': -3.4321532327220154,
#   '10%': -2.56719413172842,
#   '5%': -2.862336767636517},
#  16642.822304301197)

# %%
dfout=pd.Series(dfset[0:4],index=['Test statistic','p-value','#Lags used','Number of observations used'])

# %%
dfout
# Out:
# Test statistic                   -4.444805
# p-value                           0.000247
# #Lags used                       20.000000
# Number of observations used    3629.000000
# dtype: float64

# %%
for key, value in dfset[4].items():
    dfout[key]=value

# %%
dfout
# Out:
# Test statistic                   -4.444805
# p-value                           0.000247
# #Lags used                       20.000000
# Number of observations used    3629.000000
# 1%                               -3.432153
# 5%                               -2.862337
# 10%                              -2.567194
# dtype: float64

# %%
IndDataLog=np.log(IndexDataset)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(IndDataLog)

# %%
movAv=IndDataLog.rolling(window=12).mean()

# %%
movAv
# Out:
#                 Temp
# Date
# 1981-01-01       NaN
# 1981-01-02       NaN
# 1981-01-03       NaN
# 1981-01-04       NaN
# 1981-01-05       NaN
# 1981-01-06       NaN
# 1981-01-07       NaN
# 1981-01-08       NaN
# 1981-01-09       NaN
# 1981-01-10       NaN
# 1981-01-11       NaN
# 1981-01-12  2.843061
# 1981-01-13  2.825167
# 1981-01-14  2.840438
# 1981-01-15  2.864190
# 1981-01-16  2.893282
# 1981-01-17  2.915389
# 1981-01-18  2.952959
# 1981-01-19  2.962422
# 1981-01-20  2.952786
# 1981-01-21  2.937745
# 1981-01-22  2.895868
# 1981-01-23  2.886052
# 1981-01-24  2.901455
# 1981-01-25  2.900451
# 1981-01-26  2.888823
# 1981-01-27  2.867690
# 1981-01-28  2.852254
# 1981-01-29  2.828550
# 1981-01-30  2.787204
# ...              ...
# 1990-12-02  2.529168
# 1990-12-03  2.535581
# 1990-12-04  2.564687
# 1990-12-05  2.620441
# 1990-12-06  2.670336
# 1990-12-07  2.703696
# 1990-12-08  2.718997
# 1990-12-09  2.758283
# 1990-12-10  2.734120
# 1990-12-11  2.710711
# 1990-12-12  2.718833
# ...

# %%
movSTD=IndDataLog.rolling(window=12).std()
movSTD
# Out:
#                 Temp
# Date
# 1981-01-01       NaN
# 1981-01-02       NaN
# 1981-01-03       NaN
# 1981-01-04       NaN
# 1981-01-05       NaN
# 1981-01-06       NaN
# 1981-01-07       NaN
# 1981-01-08       NaN
# 1981-01-09       NaN
# 1981-01-10       NaN
# 1981-01-11       NaN
# 1981-01-12  0.148022
# 1981-01-13  0.135828
# 1981-01-14  0.152429
# 1981-01-15  0.186669
# 1981-01-16  0.182689
# 1981-01-17  0.181140
# 1981-01-18  0.192387
# 1981-01-19  0.184672
# 1981-01-20  0.193508
# 1981-01-21  0.189533
# 1981-01-22  0.227308
# 1981-01-23  0.234945
# 1981-01-24  0.219139
# 1981-01-25  0.219596
# 1981-01-26  0.213525
# 1981-01-27  0.189034
# 1981-01-28  0.181995
# 1981-01-29  0.175829
# 1981-01-30  0.130166
# ...              ...
# 1990-12-02  0.154787
# 1990-12-03  0.164181
# 1990-12-04  0.186957
# 1990-12-05  0.215190
# 1990-12-06  0.230085
# 1990-12-07  0.242123
# 1990-12-08  0.237788
# 1990-12-09  0.168565
# 1990-12-10  0.197822
# 1990-12-11  0.219254
# 1990-12-12  0.214166
# ...

# %%
plt.plot(movAv)

# %%
plt.plot(movSTD)

# %%
DLMV=IndDataLog-movAv

# %%
DLMV
# Out:
#                 Temp
# Date
# 1981-01-01       NaN
# 1981-01-02       NaN
# 1981-01-03       NaN
# 1981-01-04       NaN
# 1981-01-05       NaN
# 1981-01-06       NaN
# 1981-01-07       NaN
# 1981-01-08       NaN
# 1981-01-09       NaN
# 1981-01-10       NaN
# 1981-01-11       NaN
# 1981-01-12 -0.255297
# 1981-01-13 -0.009758
# 1981-01-14  0.227615
# 1981-01-15  0.354686
# 1981-01-16  0.136851
# 1981-01-17  0.109902
# 1981-01-18  0.257885
# 1981-01-19 -0.088857
# 1981-01-20 -0.211946
# 1981-01-21 -0.036323
# 1981-01-22 -0.402662
# 1981-01-23 -0.218824
# 1981-01-24 -0.128866
# 1981-01-25 -0.097090
# 1981-01-26  0.039700
# 1981-01-27  0.097584
# 1981-01-28 -0.007345
# 1981-01-29 -0.087710
# 1981-01-30 -0.072509
# ...              ...
# 1990-12-02  0.051049
# 1990-12-03  0.249430
# 1990-12-04  0.286019
# 1990-12-05  0.399984
# 1990-12-06  0.335347
# 1990-12-07  0.261577
# 1990-12-08  0.021843
# 1990-12-09 -0.112108
# 1990-12-10 -0.336225
# 1990-12-11 -0.303766
# 1990-12-12 -0.079775
# ...

# %%
DLMV.head()
# Out:
#             Temp
# Date
# 1981-01-01   NaN
# 1981-01-02   NaN
# 1981-01-03   NaN
# 1981-01-04   NaN
# 1981-01-05   NaN

# %%
DLMV.dropna(inplace=True)

# %%
DLMV
# Out:
#                 Temp
# Date
# 1981-01-12 -0.255297
# 1981-01-13 -0.009758
# 1981-01-14  0.227615
# 1981-01-15  0.354686
# 1981-01-16  0.136851
# 1981-01-17  0.109902
# 1981-01-18  0.257885
# 1981-01-19 -0.088857
# 1981-01-20 -0.211946
# 1981-01-21 -0.036323
# 1981-01-22 -0.402662
# 1981-01-23 -0.218824
# 1981-01-24 -0.128866
# 1981-01-25 -0.097090
# 1981-01-26  0.039700
# 1981-01-27  0.097584
# 1981-01-28 -0.007345
# 1981-01-29 -0.087710
# 1981-01-30 -0.072509
# 1981-01-31 -0.041237
# 1981-02-01 -0.046669
# 1981-02-02  0.156632
# 1981-02-03  0.259821
# 1981-02-04  0.137097
# 1981-02-05 -0.047288
# 1981-02-06 -0.036813
# 1981-02-07 -0.156545
# 1981-02-08  0.012028
# 1981-02-09  0.360661
# 1981-02-10 -0.147432
# ...              ...
# 1990-12-02  0.051049
# 1990-12-03  0.249430
# 1990-12-04  0.286019
# 1990-12-05  0.399984
# 1990-12-06  0.335347
# 1990-12-07  0.261577
# 1990-12-08  0.021843
# 1990-12-09 -0.112108
# 1990-12-10 -0.336225
# 1990-12-11 -0.303766
# 1990-12-12 -0.079775
# ...

# %%
plt.plot(DLMV)
plt.plot(movAv)
plt.plot(movSTD)

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    rolmean = pd.rolling_mean(timeseries, window=12)
    rolstd = pd.rolling_std(timeseries, window=12)
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean &amp; Standard Deviation')
    plt.show(block=False)

# %%
test_stationarity(IndDataLog)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:3: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=12,center=False).mean()
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:4: FutureWarning: pd.rolling_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=12,center=False).std()
#   after removing the cwd from sys.path.

# %%
plt.plot(IndDataLog, color='blue',label='Original')

# %%
plt.plot(pd.rolling_mean(IndDataLog, window=12), color='blue',label='Original')
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=12,center=False).mean()
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(pd.rolling_std(IndDataLog, window=12), color='blue',label='Original')
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: FutureWarning: pd.rolling_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=12,center=False).std()
#   """Entry point for launching an IPython kernel.

# %%
df_Log = np.log(IndDataLog)
moving_avg = pd.rolling_mean(df_Log,6)
plt.plot(movSTD)
plt.plot(movAv, color="red")
plt.show()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:2: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=6,center=False).mean()

# %%
df_log_moving_avg_diff = df_Log-moving_avg
df_log_moving_avg_diff.dropna(inplace=True)
test_stationarity(df_log_moving_avg_diff)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:3: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=12,center=False).mean()
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:4: FutureWarning: pd.rolling_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=12,center=False).std()
#   after removing the cwd from sys.path.

# %%
df_Log_diff = df_Log-df_Log.shift()
plt.plot(df_Log_diff)
